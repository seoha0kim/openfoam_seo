% %%
[model,sb] = m_cfd_of_201003
% Out:
% No port asigned (no p_comsol) !
% No comsol mphserver running or already connected!
%
% model =
%
% COMSOL Model Object
% Name: rib_upper_turbulent_SST_Re200000.mph
% Tag: Model1
% Identifier: root
%
%
% model =
%
% COMSOL Model Object
% Name: rib_lower_turbulent_SST_Re200000.mph
% Tag: Model2
% Identifier: root
%
%
% model =
%
% COMSOL Model Object
% Name: rib_lower_turbulent_SST_Re200000.mph
% Tag: Model2
% Identifier: root
%
%
% sb =
%
%   struct with fields:
%
%           v: [1x1 struct]
%          b4: [1x1 struct]
%          b3: [1x1 struct]
%     box_ids: [7x1 java.lang.String[]]
%       box_n: 7
%      id_box: [5 6 7 1 2 3 4]
%         box: [1x7 struct]

% %%
who
% Out:
% Your variables are:
%
% model  sb

% %%
sb
% Out:
% sb =
%
%   struct with fields:
%
%           v: [1x1 struct]
%          b4: [1x1 struct]
%          b3: [1x1 struct]
%     box_ids: [7x1 java.lang.String[]]
%       box_n: 7
%      id_box: [5 6 7 1 2 3 4]
%         box: [1x7 struct]

% %%
sb.
